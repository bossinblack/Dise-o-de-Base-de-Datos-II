# %% [markdown]
# # Proyecto análisis de conversación de mensajería

# %% [markdown]
# ## Cargar datos
# - Exportar una conversación personal o grupal de Whastapp o Telegram en un formato adecuado (JSON, CSV, etc), no exportar audios, archivos multimedia, etc
# - Importar archivo y convertirlo en dataframe

# %% [markdown]
# <div>
# 	<h3>Carga de Datos</h3>
# 	<div>
# 		Para este trabajo práctico, examinaremos la conversación en telegram de las materias TIF I y TIF II. El grupo fue creado el 21 de Marzo de 2021 y tiene 25 participantes.
# 	</div>
# 	<br>
# 	<div>Trabajaremos con el <a href="data/chat_tif_telegram.json">Historial</a> en formato JSON.</div>
# </div>

# %%
import pandas as pd
import requests
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime

# %%
df = pd.read_json('data/chat_tif_telegram.json')

df

msn_json = df['messages']

msn_json


msn = pd.DataFrame(msn_json.to_list())

msn
# Out:
#       id     type                 date                        actor  \
# 0      1  service  2021-03-19T09:42:03  Trabajo Integrador Final II
# 1      2  service  2021-03-19T12:08:21          Giancarlo Galvarini
# 2      3  service  2021-03-19T13:33:54          María Marta Arrieta
# 3      4  message  2021-03-19T13:36:55                          NaN
# 4      5  message  2021-03-19T13:37:34                          NaN
# ..   ...      ...                  ...                          ...
# 716  725  message  2021-09-07T10:59:50                          NaN
# 717  726  message  2021-09-07T11:33:56                          NaN
# 718  727  message  2021-09-07T11:34:16                          NaN
# 719  728  message  2021-09-10T08:30:05                          NaN
# 720  729  message  2021-09-10T08:30:11                          NaN
#
#               actor_id              action                       title  \
# 0    channel1245464638  migrate_from_group  Trabajo Integrador Final I
# 1       user1009916191  join_group_by_link                         NaN
# 2       user1691333349  join_group_by_link                         NaN
# 3                  NaN                 NaN                         NaN
# 4                  NaN                 NaN                         NaN
# ..                 ...                 ...                         ...
# 716                NaN                 NaN                         NaN
# 717                NaN                 NaN                         NaN
# 718                NaN                 NaN                         NaN
# 719                NaN                 NaN                         NaN
# 720                NaN                 NaN                         NaN
#
#                                                   text inviter  \
# 0                                                          NaN
# 1                                                        Group
# 2                                                        Group
# 3    Un verdadero placer haber compartido con Uds. ...     NaN
# 4                           Igualmente profe! Un gusto     NaN
# ..                                                 ...     ...
# 716                                   Gracias profe! 😁     NaN
# 717                            Hola profe, igualmente!     NaN
# 718                                    Gracias profe!!     NaN
# 719     Buen dia !!!Nos reunimos en 30 minutos !!! 🥐☕🫖     NaN
# 720  [ID de la reunión\n, {'type': 'link', 'text': ...     NaN
#
#                      from  ... photo width  height file  thumbnail  \
# 0                     NaN  ...   NaN   NaN     NaN  NaN        NaN
# 1                     NaN  ...   NaN   NaN     NaN  NaN        NaN
# 2                     NaN  ...   NaN   NaN     NaN  NaN        NaN
# 3     María Marta Arrieta  ...   NaN   NaN     NaN  NaN        NaN
# 4     Giancarlo Galvarini  ...   NaN   NaN     NaN  NaN        NaN
# ..                    ...  ...   ...   ...     ...  ...        ...
# 716         Pablo Fracaro  ...   NaN   NaN     NaN  NaN        NaN
# 717                  Yago  ...   NaN   NaN     NaN  NaN        NaN
# 718  Marcos Adrián Rugoso  ...   NaN   NaN     NaN  NaN        NaN
# 719   María Marta Arrieta  ...   NaN   NaN     NaN  NaN        NaN
# 720   María Marta Arrieta  ...   NaN   NaN     NaN  NaN        NaN
#
#      media_type sticker_emoji mime_type duration_seconds edited
# 0           NaN           NaN       NaN              NaN    NaN
# 1           NaN           NaN       NaN              NaN    NaN
# 2           NaN           NaN       NaN              NaN    NaN
# 3           NaN           NaN       NaN              NaN    NaN
# 4           NaN           NaN       NaN              NaN    NaN
# ..          ...           ...       ...              ...    ...
# 716         NaN           NaN       NaN              NaN    NaN
# 717         NaN           NaN       NaN              NaN    NaN
# 718         NaN           NaN       NaN              NaN    NaN
# 719         NaN           NaN       NaN              NaN    NaN
# 720         NaN           NaN       NaN              NaN    NaN
#
# [721 rows x 23 columns]

# %%
print(msn.edited.unique())
# Out:
# [nan '2021-03-31T12:56:31' '2021-04-23T14:26:12' '2021-05-09T12:57:13']

# %% [markdown]
# ## Conocer los datos
#
# - Observar que tipo de datos tiene el dataframe y que tipo de valores tiene
# - Explicar que significa cada campo y que tipo de acciones quedan registradas

# %%
msn.shape
# Out:
# (721, 23)

# %%
msn.dtypes
# Out:
# id                       int64
# type                    object
# date                    object
# actor                   object
# actor_id                object
# action                  object
# title                   object
# text                    object
# inviter                 object
# from                    object
# from_id                 object
# members                 object
# reply_to_message_id    float64
# photo                   object
# width                  float64
# height                 float64
# file                    object
# thumbnail               object
# media_type              object
# sticker_emoji           object
# mime_type               object
# duration_seconds       float64
# edited                  object
# dtype: object

# %% [markdown]
# <table >
# 	<tr>
# 		<td>
# 			<p class="normal">id</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">type</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">date</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">actor</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">actor_id</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">action</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">title</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">text</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">inviter</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">from</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">from_id</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">members</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">reply_to_message_id</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">photo</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">width</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">height</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">file</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">thumbnail</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">media_type</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">sticker_emoji</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">mime_type</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">duration_seconds</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			<p class="normal">edited</p>
# 		</td>
# 		<td>
# 			<p class="normal"></p>
# 		</td>
# 	</tr>
# </table>

# %%
msn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   721 non-null    int64
#  1   type                 721 non-null    object
#  2   date                 721 non-null    object
#  3   actor                24 non-null     object
#  4   actor_id             24 non-null     object
#  5   action               24 non-null     object
#  6   title                2 non-null      object
#  7   text                 721 non-null    object
#  8   inviter              8 non-null      object
#  9   from                 697 non-null    object
#  10  from_id              697 non-null    object
#  11  members              14 non-null     object
#  12  reply_to_message_id  54 non-null     float64
#  13  photo                21 non-null     object
#  14  width                31 non-null     float64
#  15  height               31 non-null     float64
#  16  file                 17 non-null     object
#  17  thumbnail            11 non-null     object
#  18  media_type           11 non-null     object
#  19  sticker_emoji        6 non-null      object
#  20  mime_type            11 non-null     object
#  21  duration_seconds     5 non-null      float64
#  22  edited               3 non-null      object
# dtypes: float64(4), int64(1), object(18)
# memory usage: 129.7+ KB

# %% [markdown]
# ## Datos faltantes
#
# - Analizar de manera visual y no visual si existen datos faltantes

# %%
faltantes = []
print(msn.columns)
for columna in msn.columns:
    atributo = {}
    atributo["columna"] = columna

    atributo["porcentaje"] = np.mean(msn[columna].isna())*100

    atributo["cantidad"] = np.sum(msn[columna].isna())
    faltantes.append(atributo)  

faltantes_df = pd.DataFrame(faltantes)

faltantes_df
# Out:
# Index(['id', 'type', 'date', 'actor', 'actor_id', 'action', 'title', 'text',
#        'inviter', 'from', 'from_id', 'members', 'reply_to_message_id', 'photo',
#        'width', 'height', 'file', 'thumbnail', 'media_type', 'sticker_emoji',
#        'mime_type', 'duration_seconds', 'edited'],
#       dtype='object')
#                 columna  porcentaje  cantidad
# 0                    id    0.000000         0
# 1                  type    0.000000         0
# 2                  date    0.000000         0
# 3                 actor   96.671290       697
# 4              actor_id   96.671290       697
# 5                action   96.671290       697
# 6                 title   99.722607       719
# 7                  text    0.000000         0
# 8               inviter   98.890430       713
# 9                  from    3.328710        24
# 10              from_id    3.328710        24
# 11              members   98.058252       707
# 12  reply_to_message_id   92.510402       667
# 13                photo   97.087379       700
# 14                width   95.700416       690
# 15               height   95.700416       690
# 16                 file   97.642164       704
# 17            thumbnail   98.474341       710
# 18           media_type   98.474341       710
# 19        sticker_emoji   99.167822       715
# 20            mime_type   98.474341       710
# 21     duration_seconds   99.306519       716
# 22               edited   99.583911       718

# %% [markdown]
# - Tratar datos faltantes en el caso que los haya
# - Explicar qué método se utilizó y por qué

# %%
sns.heatmap(msn.isna(), cbar=False)

# %%
faltantes_df
# Out:
#                 columna  porcentaje  cantidad
# 0                    id    0.000000         0
# 1                  type    0.000000         0
# 2                  date    0.000000         0
# 3                 actor   96.671290       697
# 4              actor_id   96.671290       697
# 5                action   96.671290       697
# 6                 title   99.722607       719
# 7                  text    0.000000         0
# 8               inviter   98.890430       713
# 9                  from    3.328710        24
# 10              from_id    3.328710        24
# 11              members   98.058252       707
# 12  reply_to_message_id   92.510402       667
# 13                photo   97.087379       700
# 14                width   95.700416       690
# 15               height   95.700416       690
# 16                 file   97.642164       704
# 17            thumbnail   98.474341       710
# 18           media_type   98.474341       710
# 19        sticker_emoji   99.167822       715
# 20            mime_type   98.474341       710
# 21     duration_seconds   99.306519       716
# 22               edited   99.583911       718

# %% [markdown]
# Decidimos borrar las columnas que tienen más del 90% de valores faltantes

# %%
msn_notna = msn.copy(deep=False)

# %%
df_fl_c = faltantes_df.loc[(faltantes_df['porcentaje'] > 90)]
print(df_fl_c)

msn_notna = msn_notna.drop(df_fl_c['columna'], axis=1)
# Out:
#                 columna  porcentaje  cantidad
# 3                 actor   96.671290       697
# 4              actor_id   96.671290       697
# 5                action   96.671290       697
# 6                 title   99.722607       719
# 8               inviter   98.890430       713
# 11              members   98.058252       707
# 12  reply_to_message_id   92.510402       667
# 13                photo   97.087379       700
# 14                width   95.700416       690
# 15               height   95.700416       690
# 16                 file   97.642164       704
# 17            thumbnail   98.474341       710
# 18           media_type   98.474341       710
# 19        sticker_emoji   99.167822       715
# 20            mime_type   98.474341       710
# 21     duration_seconds   99.306519       716
# 22               edited   99.583911       718

# %%
msn_notna = msn_notna.sort_values(by=['id'], axis=0, ascending=False)
msn_notna.head(30)
# Out:
#       id     type                 date  \
# 720  729  message  2021-09-10T08:30:11
# 719  728  message  2021-09-10T08:30:05
# 718  727  message  2021-09-07T11:34:16
# 717  726  message  2021-09-07T11:33:56
# 716  725  message  2021-09-07T10:59:50
# 715  724  message  2021-09-07T10:57:22
# 714  723  message  2021-09-07T10:56:54
# 713  722  message  2021-09-07T10:07:11
# 712  721  message  2021-09-04T07:49:41
# 711  720  message  2021-09-04T07:49:29
# 710  716  message  2021-09-03T13:42:00
# 709  715  message  2021-09-03T13:38:31
# 708  714  message  2021-09-03T13:38:10
# 707  713  message  2021-09-03T13:37:57
# 706  712  message  2021-09-03T13:36:57
# 705  711  message  2021-09-03T13:36:28
# 704  709  message  2021-09-03T05:33:30
# 703  708  message  2021-08-30T20:11:47
# 702  707  message  2021-08-30T20:04:31
# 701  706  message  2021-08-30T20:03:13
# 700  705  message  2021-08-30T20:02:17
# 699  703  message  2021-08-30T19:54:30
# 698  702  message  2021-08-30T19:53:45
# 697  701  message  2021-08-30T19:53:34
# 696  700  message  2021-08-30T19:35:58
# 695  699  message  2021-08-30T19:35:26
# 694  698  message  2021-08-30T19:34:44
# 693  697  message  2021-08-30T19:34:02
# 692  696  message  2021-08-30T15:40:09
# 691  695  message  2021-08-30T15:37:48
#
#                                                   text                  from  \
# 720  [ID de la reunión\n, {'type': 'link', 'text': ...   María Marta Arrieta
# 719     Buen dia !!!Nos reunimos en 30 minutos !!! 🥐☕🫖   María Marta Arrieta
# 718                                    Gracias profe!!  Marcos Adrián Rugoso
# 717                            Hola profe, igualmente!                  Yago
# 716                                   Gracias profe! 😁         Pablo Fracaro
# 715                                   Gracias profe! 🤗        Ornella Grasso
# 714                        Gracias, profe. Igualmente!               Esteban
# 713  Hola Equipo!!!! Sólo pensé en Uds. ...y les de...   María Marta Arrieta
# 712  [Unirse con Google Meet\n, {'type': 'link', 't...   María Marta Arrieta
# 711  Buen dia Equipo. ☕☕☕🥐🥐 Los esperamos -como pre...   María Marta Arrieta
# 710                                    Genial profe 👍🏻               Arian M
# 709     Les mando link mañana y así los despierto 😜😜😜😜   María Marta Arrieta
# 708                     Mañana nos reunimos a las 8:30   María Marta Arrieta
# 707  Porfi quienes no asistieron a clases no dejen ...   María Marta Arrieta
# 706                   Buenísimo profe, muchas gracias!             Facu Luna
# 705  Todo subido en la pestaña CLASES de la Catedra...   María Marta Arrieta
# 704  [Estimados miembros TIF 2 , ESPERANDO SINCERAM...   María Marta Arrieta
# 703                                Ahi me anote profe!     Santiago Martinez
# 702                         Apreté cualquier cosa🙈🙈🙈🙈🙈   María Marta Arrieta
# 701  Los nombres son de los alumnos  que están en l...   María Marta Arrieta
# 700                                   En reunión sorry   María Marta Arrieta
# 699                                                            Pablo Fracaro
# 698                      Por ejemplo Santiago Martínez         Pablo Fracaro
# 697  Profe me parece que faltan nombres en el formu...         Pablo Fracaro
# 696  Esto es"autovevaluación y co-evaluación" ADELA...   María Marta Arrieta
# 695  [{'type': 'link', 'text': 'https://bit.ly/3yvN...   María Marta Arrieta
# 694  Por cualquier cosa que no les haya llegado el ...   María Marta Arrieta
# 693  Buenas tardes, les debe haber llegado a vuestr...   María Marta Arrieta
# 692  Aqui les adjunto también el logo de la FI !!! ...   María Marta Arrieta
# 691                         Claro es con mail de la UM   María Marta Arrieta
#
#             from_id
# 720  user1691333349
# 719  user1691333349
# 718  user1052727325
# 717   user810386556
# 716   user830260616
# 715   user741547599
# 714   user859940597
# 713  user1691333349
# 712  user1691333349
# 711  user1691333349
# 710   user597215828
# 709  user1691333349
# 708  user1691333349
# 707  user1691333349
# 706   user672006577
# 705  user1691333349
# 704  user1691333349
# 703   user807010702
# 702  user1691333349
# 701  user1691333349
# 700  user1691333349
# 699   user830260616
# 698   user830260616
# 697   user830260616
# 696  user1691333349
# 695  user1691333349
# 694  user1691333349
# 693  user1691333349
# 692  user1691333349
# 691  user1691333349

# %%
sns.heatmap(msn_notna.isna(), cbar=False)

# %%
faltantes = []
for columna in msn_notna.columns:
    atributo = {}
    atributo["columna"] = columna

    atributo["porcentaje"] = np.mean(msn_notna[columna].isna())*100

    atributo["cantidad"] = np.sum(msn_notna[columna].isna())
    faltantes.append(atributo)  

faltantes_df = pd.DataFrame(faltantes)

faltantes_df
# Out:
#    columna  porcentaje  cantidad
# 0       id     0.00000         0
# 1     type     0.00000         0
# 2     date     0.00000         0
# 3     text     0.00000         0
# 4     from     3.32871        24
# 5  from_id     3.32871        24

# %% [markdown]
# Vemos que todavía faltan datos de los atributos from y from_id. Analizando esos atributos:

# %%
msn_notna_faltantes = msn_notna.loc[msn_notna['from'].isna()]
msn_notna_faltantes
# Out:
#       id     type                 date text from from_id
# 661  665  service  2021-08-23T12:23:50       NaN     NaN
# 493  497  service  2021-06-11T09:07:44       NaN     NaN
# 411  415  service  2021-05-20T12:15:34       NaN     NaN
# 351  355  service  2021-05-10T17:07:29       NaN     NaN
# 265  269  service  2021-04-29T16:31:51       NaN     NaN
# 33    34  service  2021-03-26T12:05:06       NaN     NaN
# 31    32  service  2021-03-26T11:51:23       NaN     NaN
# 30    31  service  2021-03-26T09:04:13       NaN     NaN
# 29    30  service  2021-03-26T09:04:07       NaN     NaN
# 27    28  service  2021-03-24T13:43:01       NaN     NaN
# 26    27  service  2021-03-22T12:17:53       NaN     NaN
# 25    26  service  2021-03-22T10:09:25       NaN     NaN
# 24    25  service  2021-03-22T09:58:12       NaN     NaN
# 23    24  service  2021-03-22T09:55:23       NaN     NaN
# 22    23  service  2021-03-22T09:25:10       NaN     NaN
# 21    22  service  2021-03-22T09:24:39       NaN     NaN
# 12    13  service  2021-03-19T16:59:36       NaN     NaN
# 11    12  service  2021-03-19T14:41:21       NaN     NaN
# 10    11  service  2021-03-19T14:41:21       NaN     NaN
# 9     10  service  2021-03-19T14:40:48       NaN     NaN
# 8      9  service  2021-03-19T14:23:09       NaN     NaN
# 2      3  service  2021-03-19T13:33:54       NaN     NaN
# 1      2  service  2021-03-19T12:08:21       NaN     NaN
# 0      1  service  2021-03-19T09:42:03       NaN     NaN

# %% [markdown]
# Los atributos from y from_id indican el usuario que envió el mensaje y su id. Vemos qué, para los registros a los que les fataltan estos dos atributos, el tipo de mensaje (atributo type) siempre corresponde a "service", es decir a aquellos mensajes de información que envía telegram. Decidimos borrar estos registros.

# %%
index = msn_notna.index

condition = msn_notna["from"].isna()

faltantes_msn_from_index = index[condition]

faltantes_msn_from_index_list = faltantes_msn_from_index.tolist()


print(faltantes_msn_from_index_list)


msn_notna = msn_notna.drop(labels=faltantes_msn_from_index_list, axis=0)
msn_notna
# Out:
# [661, 493, 411, 351, 265, 33, 31, 30, 29, 27, 26, 25, 24, 23, 22, 21, 12, 11, 10, 9, 8, 2, 1, 0]
#       id     type                 date  \
# 720  729  message  2021-09-10T08:30:11
# 719  728  message  2021-09-10T08:30:05
# 718  727  message  2021-09-07T11:34:16
# 717  726  message  2021-09-07T11:33:56
# 716  725  message  2021-09-07T10:59:50
# ..   ...      ...                  ...
# 7      8  message  2021-03-19T13:53:27
# 6      7  message  2021-03-19T13:39:41
# 5      6  message  2021-03-19T13:37:53
# 4      5  message  2021-03-19T13:37:34
# 3      4  message  2021-03-19T13:36:55
#
#                                                   text                  from  \
# 720  [ID de la reunión\n, {'type': 'link', 'text': ...   María Marta Arrieta
# 719     Buen dia !!!Nos reunimos en 30 minutos !!! 🥐☕🫖   María Marta Arrieta
# 718                                    Gracias profe!!  Marcos Adrián Rugoso
# 717                            Hola profe, igualmente!                  Yago
# 716                                   Gracias profe! 😁         Pablo Fracaro
# ..                                                 ...                   ...
# 7    Gravias profe por la clase de hoy. Extrañaba l...           Matias Ruiz
# 6    Gran desafío y junto a Uds , con Uds  y por Ud...   María Marta Arrieta
# 5    Gracias María Marta!!! Un placer por fin tener...        Daiana Ascurra
# 4                           Igualmente profe! Un gusto   Giancarlo Galvarini
# 3    Un verdadero placer haber compartido con Uds. ...   María Marta Arrieta
#
#             from_id
# 720  user1691333349
# 719  user1691333349
# 718  user1052727325
# 717   user810386556
# 716   user830260616
# ..              ...
# 7     user857392417
# 6    user1691333349
# 5     user867417470
# 4    user1009916191
# 3    user1691333349
#
# [697 rows x 6 columns]

# %%
sns.heatmap(msn_notna.isna(), cbar=False)

# %% [markdown]
# ## Outliers
#
# - Analizar de manera visual y no visual si existen valores atípicos para cada valor no categórico

# %%
msn_notna.dtypes
# Out:
# id          int64
# type       object
# date       object
# text       object
# from       object
# from_id    object
# dtype: object

# %%
#msn_notna['date']= pd.to_datetime(msn_notna['date'], format='%Y-%m-%dT%H:%M%S')
msn_notna['date'] = pd.to_datetime(msn_notna['date'], format='%Y-%m-%dT%H:%M:%S')
msn_notna['text_length']  = msn_notna['text'].str.len()
msn_notna
# Out:
#       id     type                date  \
# 720  729  message 2021-09-10 08:30:11
# 719  728  message 2021-09-10 08:30:05
# 718  727  message 2021-09-07 11:34:16
# 717  726  message 2021-09-07 11:33:56
# 716  725  message 2021-09-07 10:59:50
# ..   ...      ...                 ...
# 7      8  message 2021-03-19 13:53:27
# 6      7  message 2021-03-19 13:39:41
# 5      6  message 2021-03-19 13:37:53
# 4      5  message 2021-03-19 13:37:34
# 3      4  message 2021-03-19 13:36:55
#
#                                                   text                  from  \
# 720  [ID de la reunión\n, {'type': 'link', 'text': ...   María Marta Arrieta
# 719     Buen dia !!!Nos reunimos en 30 minutos !!! 🥐☕🫖   María Marta Arrieta
# 718                                    Gracias profe!!  Marcos Adrián Rugoso
# 717                            Hola profe, igualmente!                  Yago
# 716                                   Gracias profe! 😁         Pablo Fracaro
# ..                                                 ...                   ...
# 7    Gravias profe por la clase de hoy. Extrañaba l...           Matias Ruiz
# 6    Gran desafío y junto a Uds , con Uds  y por Ud...   María Marta Arrieta
# 5    Gracias María Marta!!! Un placer por fin tener...        Daiana Ascurra
# 4                           Igualmente profe! Un gusto   Giancarlo Galvarini
# 3    Un verdadero placer haber compartido con Uds. ...   María Marta Arrieta
#
#             from_id  text_length
# 720  user1691333349            3
# 719  user1691333349           46
# 718  user1052727325           15
# 717   user810386556           23
# 716   user830260616           16
# ..              ...          ...
# 7     user857392417           62
# 6    user1691333349           63
# 5     user867417470           59
# 4    user1009916191           26
# 3    user1691333349          190
#
# [697 rows x 7 columns]

# %%
msn_notna.dtypes
# Out:
# id                      int64
# type                   object
# date           datetime64[ns]
# text                   object
# from                   object
# from_id                object
# text_length             int64
# dtype: object

# %%
msn_notna['date_only'] = [d.date() for d in msn_notna['date']]
msn_notna['time_only'] = [d.time() for d in msn_notna['date']]
msn_notna['hour_only'] = pd.to_datetime(msn_notna['date'], format='%Y-%m-%dT%H:%M:%S').dt.hour
msn_notna_atypical_hours = msn_notna[(msn_notna['time_only']>datetime.time(1,0,0)) & (msn_notna['time_only']<datetime.time(6,0,0)) ]
msn_notna.to_csv('data/clean_chat.csv')
msn_notna
# Out:
#       id     type                date  \
# 720  729  message 2021-09-10 08:30:11
# 719  728  message 2021-09-10 08:30:05
# 718  727  message 2021-09-07 11:34:16
# 717  726  message 2021-09-07 11:33:56
# 716  725  message 2021-09-07 10:59:50
# ..   ...      ...                 ...
# 7      8  message 2021-03-19 13:53:27
# 6      7  message 2021-03-19 13:39:41
# 5      6  message 2021-03-19 13:37:53
# 4      5  message 2021-03-19 13:37:34
# 3      4  message 2021-03-19 13:36:55
#
#                                                   text                  from  \
# 720  [ID de la reunión\n, {'type': 'link', 'text': ...   María Marta Arrieta
# 719     Buen dia !!!Nos reunimos en 30 minutos !!! 🥐☕🫖   María Marta Arrieta
# 718                                    Gracias profe!!  Marcos Adrián Rugoso
# 717                            Hola profe, igualmente!                  Yago
# 716                                   Gracias profe! 😁         Pablo Fracaro
# ..                                                 ...                   ...
# 7    Gravias profe por la clase de hoy. Extrañaba l...           Matias Ruiz
# 6    Gran desafío y junto a Uds , con Uds  y por Ud...   María Marta Arrieta
# 5    Gracias María Marta!!! Un placer por fin tener...        Daiana Ascurra
# 4                           Igualmente profe! Un gusto   Giancarlo Galvarini
# 3    Un verdadero placer haber compartido con Uds. ...   María Marta Arrieta
#
#             from_id  text_length   date_only time_only  hour_only
# 720  user1691333349            3  2021-09-10  08:30:11          8
# 719  user1691333349           46  2021-09-10  08:30:05          8
# 718  user1052727325           15  2021-09-07  11:34:16         11
# 717   user810386556           23  2021-09-07  11:33:56         11
# 716   user830260616           16  2021-09-07  10:59:50         10
# ..              ...          ...         ...       ...        ...
# 7     user857392417           62  2021-03-19  13:53:27         13
# 6    user1691333349           63  2021-03-19  13:39:41         13
# 5     user867417470           59  2021-03-19  13:37:53         13
# 4    user1009916191           26  2021-03-19  13:37:34         13
# 3    user1691333349          190  2021-03-19  13:36:55         13
#
# [697 rows x 10 columns]

# %%
msn_notna_atypical_hours
# Out:
#       id     type                date  \
# 704  709  message 2021-09-03 05:33:30
#
#                                                   text                 from  \
# 704  [Estimados miembros TIF 2 , ESPERANDO SINCERAM...  María Marta Arrieta
#
#             from_id  text_length   date_only time_only  hour_only
# 704  user1691333349            3  2021-09-03  05:33:30          5

# %%
msn_notna.describe()
# Out:
#                id  text_length   hour_only
# count  697.000000   697.000000  697.000000
# mean   372.139168    59.431851   14.751793
# std    204.635671    94.657937    4.063798
# min      4.000000     0.000000    5.000000
# 25%    196.000000    14.000000   12.000000
# 50%    373.000000    30.000000   14.000000
# 75%    549.000000    62.000000   19.000000
# max    729.000000   872.000000   22.000000

# %% [markdown]
# - Si existen valores atípicos, ¿estos son causados por errores en la carga de datos o por otra razón?. Explicar la razón

# %%
Q1 = msn_notna.quantile(0.25)
Q3 = msn_notna.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# id             353.0
# text_length     48.0
# hour_only        7.0
# dtype: float64

# %%
rango_inferior = Q1 - 1.5 * IQR
rango_superior = Q3 + 1.5 * IQR

print("Rango superior")
print(rango_inferior)

print("\nRango inferior")
print(rango_superior)
# Out:
# Rango superior
# id            -333.5
# text_length    -58.0
# hour_only        1.5
# dtype: float64
#
# Rango inferior
# id             1078.5
# text_length     134.0
# hour_only        29.5
# dtype: float64

# %%
msn_notna_outliers = (df < rango_inferior) | (df > rango_superior)
msn_notna_outliers
# Out:
#      hour_only    id  messages   name  text_length   type
# 0        False  True     False  False        False  False
# 1        False  True     False  False        False  False
# 2        False  True     False  False        False  False
# 3        False  True     False  False        False  False
# 4        False  True     False  False        False  False
# ..         ...   ...       ...    ...          ...    ...
# 716      False  True     False  False        False  False
# 717      False  True     False  False        False  False
# 718      False  True     False  False        False  False
# 719      False  True     False  False        False  False
# 720      False  True     False  False        False  False
#
# [721 rows x 6 columns]

# %%
sns.heatmap(msn_notna_outliers, cbar=False)

# %%
msn_notna_outliers.boxplot(column='hour_only')

# %%
msn_notna_outliers.text_length.hist()
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
