# %% [markdown]
# # TP1
#
# ## Repositorios de información

# %% [markdown]
# ## Ejercicio 1
#
# - Descomprimir el archivo clima.tgz de la carpeta data
# - Convertir cada archivo a Dataframe y mostrarlo en pantalla

# %%
import pandas as pd
import tarfile
import os
import requests

# %%
objetoTar = tarfile.open("data/clima.tgz")
objetoTar.extractall("data/clima")
objetoTar.close()


for filename in os.listdir('data/clima'):
    print(filename)
    file = 'data/clima/'+filename
    print(file)
    df = pd.read_csv(file, delimiter = "\t", encoding='utf8')
    print(df)
# Out:
# agosto08.txt
# data/clima/agosto08.txt
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-9be2ca8b3c6c> in <module>
#      12     file = 'data/clima/'+filename
#      13     print(file)
# ---> 14     df = pd.read_csv(file, delimiter = "\t", encoding='utf8')
#      15     print(df)
#      16
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 96: invalid continuation byte

# %% [markdown]
# ## Ejercicio 2
#
# - Obtener de la API de <a href="https://wikimedia.org/api/rest_v1/#/Pageviews%20data">Wikimedia </a> la cantidad de visitas en este año a la página Albert Einstein por día.
# - Mostrar el Dataframe obtenido por pantalla

# %%
from datetime import datetime
today = datetime.today().strftime('%Y%m%d')

url = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/commons.wikimedia.org/all-access/all-agents/Albert_Einstein/daily/20210101/'+today
print(url)

r = requests.get(url).text

print(r)

df = pd.DataFrame(data)
df
# Out:
# https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/commons.wikimedia.org/all-access/all-agents/Albert_Einstein/daily/20210101/20210830
# <!DOCTYPE html>
# <html lang="en">
# <meta charset="utf-8">
# <title>Wikimedia Error</title>
# <style>
# * { margin: 0; padding: 0; }
# body { background: #fff; font: 15px/1.6 sans-serif; color: #333; }
# .content { margin: 7% auto 0; padding: 2em 1em 1em; max-width: 640px; }
# .footer { clear: both; margin-top: 14%; border-top: 1px solid #e5e5e5; background: #f9f9f9; padding: 2em 0; font-size: 0.8em; text-align: center; }
# img { float: left; margin: 0 2em 2em 0; }
# a img { border: 0; }
# h1 { margin-top: 1em; font-size: 1.2em; }
# .content-text { overflow: hidden; overflow-wrap: break-word; word-wrap: break-word; -webkit-hyphens: auto; -moz-hyphens: auto; -ms-hyphens: auto; hyphens: auto; }
# p { margin: 0.7em 0 1em 0; }
# a { color: #0645ad; text-decoration: none; }
# a:hover { text-decoration: underline; }
# code { font-family: sans-serif; }
# .text-muted { color: #777; }
# </style>
# <div class="content" role="main">
# <a href="https://www.wikimedia.org"><img src="https://www.wikimedia.org/static/images/wmf-logo.png" srcset="https://www.wikimedia.org/static/images/wmf-logo-2x.png 2x" alt="Wikimedia" width="135" height="101">
# </a>
# <h1>Error</h1>
# <div class="content-text">
# <p>Our servers are currently under maintenance or experiencing a technical problem.
#
# Please <a href="" title="Reload this page" onclick="window.location.reload(false); return false">try again</a> in a few&nbsp;minutes.</p>
#
# <p>See the error message at the bottom of this page for more&nbsp;information.</p>
# </div>
# </div>
# <div class="footer"><p>If you report this error to the Wikimedia System Administrators, please include the details below.</p><p class="text-muted"><code>Request from 190.122.181.2 via cp1083 cp1083, Varnish XID 115618315<br>Upstream caches: cp1083 int<br>Error: 403, Scripted requests from your IP have been blocked, please see https://meta.wikimedia.org/wiki/User-Agent_policy. In case of further questions, please contact noc@wikimedia.org. at Mon, 30 Aug 2021 15:23:30 GMT</code></p>
# </div>
# </html>
#           date                                          localName  \
# 0   2021-01-01                                          Año Nuevo
# 1   2021-02-15                                           Carnaval
# 2   2021-02-16                                           Carnaval
# 3   2021-03-24  Día Nacional de la Memoria por la Verdad y la ...
# 4   2021-04-02  Día del Veterano y de los Caídos en la Guerra ...
# 5   2021-04-02                                      Viernes Santo
# 6   2021-05-01                                 Día del Trabajador
# 7   2021-05-25                       Día de la Revolución de Mayo
# 8   2021-06-17  Paso a la Inmortalidad del General Martín Migu...
# 9   2021-06-20  Paso a la Inmortalidad del General Manuel Belg...
# 10  2021-07-09                            Día de la Independencia
# 11  2021-08-16  Paso a la Inmortalidad del General José de San...
# 12  2021-10-11           Día del Respeto a la Diversidad Cultural
# 13  2021-11-20                       Día de la Soberanía Nacional
# 14  2021-12-08           Día de la Inmaculada Concepción de María
# 15  2021-12-25                                            Navidad
#
#                                                  name countryCode  fixed  \
# 0                                      New Year's Day          AR   True
# 1                                            Carnival          AR  False
# 2                                            Carnival          AR  False
# 3            Day of Remembrance for Truth and Justice          AR   True
# 4   Day of the Veterans and Fallen of the Malvinas...          AR   True
# 5                                         Good Friday          AR  False
# 6                                          Labour Day          AR   True
# 7                                      May Revolution          AR   True
# 8   Anniversary of the Passing of General Martín M...          AR   True
# 9                General Manuel Belgrano Memorial Day          AR   True
# 10                                   Independence Day          AR   True
# 11            General José de San Martín Memorial Day          AR  False
# 12              Day of Respect for Cultural Diversity          AR  False
# 13                           National Sovereignty Day          AR   True
# 14                          Immaculate Conception Day          AR   True
# 15                                      Christmas Day          AR   True
#
#     global counties  launchYear    type
# 0     True     None         NaN  Public
# 1     True     None         NaN  Public
# 2     True     None         NaN  Public
# 3     True     None         NaN  Public
# 4     True     None         NaN  Public
# 5     True     None         NaN  Public
# 6     True     None         NaN  Public
# 7     True     None         NaN  Public
# 8     True     None      2016.0  Public
# 9     True     None         NaN  Public
# 10    True     None         NaN  Public
# 11    True     None         NaN  Public
# 12    True     None         NaN  Public
# 13    True     None         NaN  Public
# 14    True     None         NaN  Public
# 15    True     None         NaN  Public

# %% [markdown]
# ## Ejercicio 3
#
# - Crear una base de datos MySQL
# - Crear una tabla que contenga nombre, apellido y teléfono
# - Obtener de la base de datos la lista de personas ordenada por apellido de forma descendente
# - Mostrar el Dataframe resultante por pantalla

# %%
import mysql.connector as connection

db = connection.connect(host="localhost", database = 'db2021',user="root", passwd="javier10",use_pure=True)

query = "select * from usuarios order by apellido DESC;"

df = pd.read_sql(query,db)

db.close()
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-bafa59688401> in <module>
#       1 # Importar conector mysql
# ----> 2 import mysql.connector as connection
#       3 # Crear conexión a la db
#       4 db = connection.connect(host="localhost", database = 'db2021',user="root", passwd="javier10",use_pure=True)
#       5 # Consulta
#
# ModuleNotFoundError: No module named 'mysql'

# %% [markdown]
# ## Ejercicio 4
#
# - Obtener de la API <a href="https://date.nager.at/swagger/index.html">Nager.Date</a> las fiestas nacionales argentinas para el 2021
# - Mostrar el dataframe resultante por pantalla

# %%
from datetime import datetime
today = datetime.today().strftime('%Y')

url = 'https://date.nager.at/api/v1/Get/ar/'+today
print(url)

r = requests.get(url)

data = r.json()

df = pd.DataFrame(data)
df
# Out:
# https://date.nager.at/api/v1/Get/ar/2021
#           date                                          localName  \
# 0   2021-01-01                                          Año Nuevo
# 1   2021-02-15                                           Carnaval
# 2   2021-02-16                                           Carnaval
# 3   2021-03-24  Día Nacional de la Memoria por la Verdad y la ...
# 4   2021-04-02  Día del Veterano y de los Caídos en la Guerra ...
# 5   2021-04-02                                      Viernes Santo
# 6   2021-05-01                                 Día del Trabajador
# 7   2021-05-25                       Día de la Revolución de Mayo
# 8   2021-06-17  Paso a la Inmortalidad del General Martín Migu...
# 9   2021-06-20  Paso a la Inmortalidad del General Manuel Belg...
# 10  2021-07-09                            Día de la Independencia
# 11  2021-08-16  Paso a la Inmortalidad del General José de San...
# 12  2021-10-11           Día del Respeto a la Diversidad Cultural
# 13  2021-11-20                       Día de la Soberanía Nacional
# 14  2021-12-08           Día de la Inmaculada Concepción de María
# 15  2021-12-25                                            Navidad
#
#                                                  name countryCode  fixed  \
# 0                                      New Year's Day          AR   True
# 1                                            Carnival          AR  False
# 2                                            Carnival          AR  False
# 3            Day of Remembrance for Truth and Justice          AR   True
# 4   Day of the Veterans and Fallen of the Malvinas...          AR   True
# 5                                         Good Friday          AR  False
# 6                                          Labour Day          AR   True
# 7                                      May Revolution          AR   True
# 8   Anniversary of the Passing of General Martín M...          AR   True
# 9                General Manuel Belgrano Memorial Day          AR   True
# 10                                   Independence Day          AR   True
# 11            General José de San Martín Memorial Day          AR  False
# 12              Day of Respect for Cultural Diversity          AR  False
# 13                           National Sovereignty Day          AR   True
# 14                          Immaculate Conception Day          AR   True
# 15                                      Christmas Day          AR   True
#
#     global counties  launchYear    type
# 0     True     None         NaN  Public
# 1     True     None         NaN  Public
# 2     True     None         NaN  Public
# 3     True     None         NaN  Public
# 4     True     None         NaN  Public
# 5     True     None         NaN  Public
# 6     True     None         NaN  Public
# 7     True     None         NaN  Public
# 8     True     None      2016.0  Public
# 9     True     None         NaN  Public
# 10    True     None         NaN  Public
# 11    True     None         NaN  Public
# 12    True     None         NaN  Public
# 13    True     None         NaN  Public
# 14    True     None         NaN  Public
# 15    True     None         NaN  Public

# %% [markdown]
# ## Ejercicio 5
#
# - Obtener una tabla informativa de una página a elección con Web Scrapping
# - Mostrar el Dataframe resultante por pantalla

# %%
url = 'https://www.bbc.com/sport/formula1/drivers-world-championship/standings'

tables = pd.read_html(url, header=0, index_col=0, skiprows=[5])

tables[0]
# Out:
#                                                                         Driver  \
# Rank
# 11                                                Lewis HamiltonLewis Hamilton
# 22                                                Max VerstappenMax Verstappen
# 33                                                    Lando NorrisLando Norris
# 44                                              Valtteri BottasValtteri Bottas
# 66                                            Carlos Sainz Jr.Carlos Sainz Jr.
# 77                                              Charles LeclercCharles Leclerc
# 88                                            Daniel RicciardoDaniel Ricciardo
# 99                                                    Pierre GaslyPierre Gasly
# 1010                                                  Esteban OconEsteban Ocon
# 1111                                            Fernando AlonsoFernando Alonso
# 1212                                          Sebastian VettelSebastian Vettel
# 1313                                                  Yuki TsunodaYuki Tsunoda
# 1414                                                  Lance StrollLance Stroll
# 1515                                              George RussellGeorge Russell
# 1616                                            Nicholas LatifiNicholas Latifi
# 1717                                              Kimi RaikkonenKimi Raikkonen
# 1818                                      Antonio GiovinazziAntonio Giovinazzi
# 1919                                            Mick SchumacherMick Schumacher
# 2020                                              Nikita MazepinNikita Mazepin
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                           Team  \
# Rank
# 11                                                            MercedesMercedes
# 22                                                            Red BullRed Bull
# 33                                                              McLarenMcLaren
# 44                                                            MercedesMercedes
# 66                                                              FerrariFerrari
# 77                                                              FerrariFerrari
# 88                                                              McLarenMcLaren
# 99                                                        AlphaTauriAlphaTauri
# 1010                                                              AlpineAlpine
# 1111                                                              AlpineAlpine
# 1212                                                  Aston MartinAston Martin
# 1313                                                      AlphaTauriAlphaTauri
# 1414                                                  Aston MartinAston Martin
# 1515                                                          WilliamsWilliams
# 1616                                                          WilliamsWilliams
# 1717                                                      Alfa RomeoAlfa Romeo
# 1818                                                      Alfa RomeoAlfa Romeo
# 1919                                                                  HaasHaas
# 2020                                                                  HaasHaas
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                           Wins  \
# Rank
# 11                                                                          44
# 22                                                                          66
# 33                                                                          00
# 44                                                                          00
# 66                                                                          00
# 77                                                                          00
# 88                                                                          00
# 99                                                                          00
# 1010                                                                        11
# 1111                                                                        00
# 1212                                                                        00
# 1313                                                                        00
# 1414                                                                        00
# 1515                                                                        00
# 1616                                                                        00
# 1717                                                                        00
# 1818                                                                        00
# 1919                                                                        00
# 2020                                                                        00
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                         Points  \
# Rank
# 11                                                                  202.5202.5
# 22                                                                  199.5199.5
# 33                                                                      113113
# 44                                                                      108108
# 66                                                                    83.583.5
# 77                                                                        8282
# 88                                                                        5656
# 99                                                                        5454
# 1010                                                                      4242
# 1111                                                                      3838
# 1212                                                                      3535
# 1313                                                                      1818
# 1414                                                                      1818
# 1515                                                                      1313
# 1616                                                                        77
# 1717                                                                        22
# 1818                                                                        11
# 1919                                                                        00
# 2020                                                                        00
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                     Unnamed: 5  \
# Rank
# 11                                                                         NaN
# 22                                                                         NaN
# 33                                                                         NaN
# 44                                                                         NaN
# 66                                                                         NaN
# 77                                                                         NaN
# 88                                                                         NaN
# 99                                                                         NaN
# 1010                                                                       NaN
# 1111                                                                       NaN
# 1212                                                                       NaN
# 1313                                                                       NaN
# 1414                                                                       NaN
# 1515                                                                       NaN
# 1616                                                                       NaN
# 1717                                                                       NaN
# 1818                                                                       NaN
# 1919                                                                       NaN
# 2020                                                                       NaN
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                     Unnamed: 6  \
# Rank
# 11                                                                         NaN
# 22                                                                         NaN
# 33                                                                         NaN
# 44                                                                         NaN
# 66                                                                         NaN
# 77                                                                         NaN
# 88                                                                         NaN
# 99                                                                         NaN
# 1010                                                                       NaN
# 1111                                                                       NaN
# 1212                                                                       NaN
# 1313                                                                       NaN
# 1414                                                                       NaN
# 1515                                                                       NaN
# 1616                                                                       NaN
# 1717                                                                       NaN
# 1818                                                                       NaN
# 1919                                                                       NaN
# 2020                                                                       NaN
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                     Unnamed: 7  \
# Rank
# 11                                                                         NaN
# 22                                                                         NaN
# 33                                                                         NaN
# 44                                                                         NaN
# 66                                                                         NaN
# 77                                                                         NaN
# 88                                                                         NaN
# 99                                                                         NaN
# 1010                                                                       NaN
# 1111                                                                       NaN
# 1212                                                                       NaN
# 1313                                                                       NaN
# 1414                                                                       NaN
# 1515                                                                       NaN
# 1616                                                                       NaN
# 1717                                                                       NaN
# 1818                                                                       NaN
# 1919                                                                       NaN
# 2020                                                                       NaN
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                     Unnamed: 8  \
# Rank
# 11                                                                         NaN
# 22                                                                         NaN
# 33                                                                         NaN
# 44                                                                         NaN
# 66                                                                         NaN
# 77                                                                         NaN
# 88                                                                         NaN
# 99                                                                         NaN
# 1010                                                                       NaN
# 1111                                                                       NaN
# 1212                                                                       NaN
# 1313                                                                       NaN
# 1414                                                                       NaN
# 1515                                                                       NaN
# 1616                                                                       NaN
# 1717                                                                       NaN
# 1818                                                                       NaN
# 1919                                                                       NaN
# 2020                                                                       NaN
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                     Unnamed: 9  \
# Rank
# 11                                                                         NaN
# 22                                                                         NaN
# 33                                                                         NaN
# 44                                                                         NaN
# 66                                                                         NaN
# 77                                                                         NaN
# 88                                                                         NaN
# 99                                                                         NaN
# 1010                                                                       NaN
# 1111                                                                       NaN
# 1212                                                                       NaN
# 1313                                                                       NaN
# 1414                                                                       NaN
# 1515                                                                       NaN
# 1616                                                                       NaN
# 1717                                                                       NaN
# 1818                                                                       NaN
# 1919                                                                       NaN
# 2020                                                                       NaN
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                    Unnamed: 10  \
# Rank
# 11                                                                         NaN
# 22                                                                         NaN
# 33                                                                         NaN
# 44                                                                         NaN
# 66                                                                         NaN
# 77                                                                         NaN
# 88                                                                         NaN
# 99                                                                         NaN
# 1010                                                                       NaN
# 1111                                                                       NaN
# 1212                                                                       NaN
# 1313                                                                       NaN
# 1414                                                                       NaN
# 1515                                                                       NaN
# 1616                                                                       NaN
# 1717                                                                       NaN
# 1818                                                                       NaN
# 1919                                                                       NaN
# 2020                                                                       NaN
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
#
#                                                                    Unnamed: 11
# Rank
# 11                                                                         NaN
# 22                                                                         NaN
# 33                                                                         NaN
# 44                                                                         NaN
# 66                                                                         NaN
# 77                                                                         NaN
# 88                                                                         NaN
# 99                                                                         NaN
# 1010                                                                       NaN
# 1111                                                                       NaN
# 1212                                                                       NaN
# 1313                                                                       NaN
# 1414                                                                       NaN
# 1515                                                                       NaN
# 1616                                                                       NaN
# 1717                                                                       NaN
# 1818                                                                       NaN
# 1919                                                                       NaN
# 2020                                                                       NaN
# Last updated 29th August 2021 at 20:10  Last updated 29th August 2021 at 20:10
